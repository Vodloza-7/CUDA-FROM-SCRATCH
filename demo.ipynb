# %%
import cupy as cp

# %%
import numpy as np

# %%
array_cpu = np.random.randint(0, 255, size=(200, 200))

# %%
array_cpu.nbytes / 1e6
# Out:
# 0.32

# %%
array_gpu = cp.asarray(array_cpu)

# %%
# %%timeit
cp.asarray(array_cpu)
# Out:
# 53.4 µs ± 1.43 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
type(array_gpu)
# Out:
# cupy.ndarray

# %%
from scipy import fft

# %%
# %%timeit
fft.fftn(array_cpu)
# Out:
# 485 µs ± 107 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
from cupyx.scipy import fft as fft_gpu

# %%
# %%timeit
fft_gpu.fftn(array_gpu)
# Out:
# 109 µs ± 51.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
array_cpu_again = cp.asnumpy(fft_gpu.fftn(array_gpu))
# Out:
# 423 µs ± 8.19 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
